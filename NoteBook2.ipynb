# %%
import pickle # Verisetlerinin notebook'a aktarılması
pickle_file_link = "/content/drive/MyDrive/Data"
X_train = pickle.load(open(f"{pickle_file_link}/X_train.pickle","rb"))
y_train = pickle.load(open(f"{pickle_file_link}/y_train.pickle","rb"))

X_test = pickle.load(open(f"{pickle_file_link}/X_test.pickle","rb"))
y_test = pickle.load(open(f"{pickle_file_link}/y_test.pickle","rb"))

X_val = pickle.load(open(f"{pickle_file_link}/X_val.pickle","rb"))
y_val = pickle.load(open(f"{pickle_file_link}/y_val.pickle","rb"))

# %%
from sklearn.metrics import confusion_matrix
import itertools
from tensorflow import keras
from keras.utils.np_utils import to_categorical # convert to one-hot-encoding
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau

# %%
model1 = Sequential() # Modelin oluşturulması
model1.add(Conv2D(filters = 32, kernel_size = 5, padding = 'same', activation = 'relu',  # Input boyutunun 28x28 olması ve grayscaled olması sebebiyle ilk katman şekli 28,28,1 olarak belirlendi.
                 input_shape = (28, 28, 1)))
model1.add(MaxPooling2D(pool_size = (5, 5)))

model1.add(Conv2D(filters = 64 , kernel_size = 5, padding = 'same', activation = 'relu'))
model1.add(MaxPooling2D(pool_size = (5, 5)))

model1.add(Conv2D(filters = 128 , kernel_size = 5, padding = 'same', activation = 'relu'))
model1.add(Dropout(0.5))

model1.add(Flatten())
model1.add(Dense(10, activation='softmax'))

model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 32)        832
#
#  max_pooling2d (MaxPooling2D  (None, 5, 5, 32)         0
#  )
#
#  conv2d_1 (Conv2D)           (None, 5, 5, 64)          51264
#
#  max_pooling2d_1 (MaxPooling  (None, 1, 1, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 1, 1, 128)         204928
#
#  dropout (Dropout)           (None, 1, 1, 128)         0
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 10)                1290
#
# =================================================================
# Total params: 258,314
# Trainable params: 258,314
# Non-trainable params: 0
# _________________________________________________________________

# %%
model1.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
hist1 = model1.fit(X_train, y_train, epochs = 50, batch_size = 64,validation_data = (X_val , y_val) )
# Out:
# Epoch 1/50
# 110/110 [==============================] - 13s 8ms/step - loss: 2.0429 - accuracy: 0.2189 - val_loss: 1.7300 - val_accuracy: 0.4021
# Epoch 2/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.7071 - accuracy: 0.3698 - val_loss: 1.5075 - val_accuracy: 0.4364
# Epoch 3/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.5051 - accuracy: 0.4465 - val_loss: 1.3258 - val_accuracy: 0.5258
# Epoch 4/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.3858 - accuracy: 0.4958 - val_loss: 1.2263 - val_accuracy: 0.5876
# Epoch 5/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.3069 - accuracy: 0.5246 - val_loss: 1.1643 - val_accuracy: 0.5911
# Epoch 6/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.2300 - accuracy: 0.5626 - val_loss: 1.1229 - val_accuracy: 0.6117
# Epoch 7/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.1863 - accuracy: 0.5757 - val_loss: 1.0740 - val_accuracy: 0.6082
# Epoch 8/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.1418 - accuracy: 0.5894 - val_loss: 1.1079 - val_accuracy: 0.6002
# Epoch 9/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.1013 - accuracy: 0.6050 - val_loss: 0.9777 - val_accuracy: 0.6472
# Epoch 10/50
# 110/110 [==============================] - 1s 5ms/step - loss: 1.0559 - accuracy: 0.6170 - val_loss: 0.9838 - val_accuracy: 0.6586
# Epoch 11/50
# 110/110 [==============================] - 0s 5ms/step - loss: 1.0230 - accuracy: 0.6375 - val_loss: 1.0767 - val_accuracy: 0.6060
# Epoch 12/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0
50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.3845 - accuracy: 0.8724 - val_loss: 0.6530 - val_accuracy: 0.8018
# Epoch 43/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.3523 - accuracy: 0.8835 - val_loss: 0.6557 - val_accuracy: 0.8030
# Epoch 44/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.3391 - accuracy: 0.8872 - val_loss: 0.6785 - val_accuracy: 0.8064
# Epoch 45/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.3356 - accuracy: 0.8869 - val_loss: 0.6886 - val_accuracy: 0.8099
# Epoch 46/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.3418 - accuracy: 0.8845 - val_loss: 0.6823 - val_accuracy: 0.8133
# Epoch 47/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.3441 - accuracy: 0.8827 - val_loss: 0.6485 - val_accuracy: 0.8087
# Epoch 48/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.3276 - accuracy: 0.8908 - val_loss: 0.8648 - val_accuracy: 0.7640
# Epoch 49/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.3063 - accuracy: 0.8985 - val_loss: 0.6602 - val_accuracy: 0.8167
# Epoch 50/50
# 110/110 [==============================] - 1s 5ms/step - loss: 0.2834 - accuracy: 0.9054 - val_loss: 0.7629 - val_accuracy: 0.7892

# %%
import matplotlib.pyplot as plt

plt.plot(hist1.history['accuracy'], label='accuracy')
plt.plot(hist1.history['val_accuracy'], label = 'val_accuracy')
plt.title("Train_Accuracy vs Validation_Accuracy")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

# %%
plt.plot(hist1.history['loss'])
plt.plot(hist1.history['val_loss'])
plt.title('Model_Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# confusion matrix
import seaborn as sns
import pandas as pd
import numpy as np
# Predict the values from the validation dataset
Y_pred = model1.predict(X_val)
# Convert predictions classes to one hot vectors 
Y_pred_classes = np.argmax(Y_pred,axis = 1) 
# Convert validation observations to one hot vectors
Y_true = np.argmax(y_val,axis = 1) 
# compute the confusion matrix
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
# plot the confusion matrix
f,ax = plt.subplots(figsize=(8, 8))
sns.heatmap(confusion_mtx, annot=True, linewidths=0.01,cmap="Greens",linecolor="gray", fmt= '.1f',ax=ax)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# %%
model = Sequential() # Model için Hyperparameters Tunning işlemi
model.add(Conv2D(filters = 64, kernel_size = 5, padding = 'same', activation = 'relu',  # Input boyutunun 28x28 olması ve grayscaled olması sebebiyle ilk katman şekli 28,28,1 olarak belirlendi.
                 input_shape = (28, 28, 1)))
model.add(Conv2D(filters = 64, kernel_size = 5, padding = 'same', activation = 'relu')) 
model.add(MaxPooling2D(pool_size = (4, 4)))
model.add(Dropout(0.5))

model.add(Conv2D(filters = 128 , kernel_size = 5, padding = 'same', activation = 'relu'))
model.add(Conv2D(filters = 128 , kernel_size = 5, padding = 'same', activation = 'relu'))
model.add(MaxPooling2D(pool_size = (4, 4)))
model.add(Dropout(0.5))

model.add(Conv2D(filters = 256 , kernel_size = 5, padding = 'same', activation = 'relu'))
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 28, 28, 64)        1664
#
#  conv2d_4 (Conv2D)           (None, 28, 28, 64)        102464
#
#  max_pooling2d_2 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 7, 7, 64)          0
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 128)         204928
#
#  conv2d_6 (Conv2D)           (None, 7, 7, 128)         409728
#
#  max_pooling2d_3 (MaxPooling  (None, 1, 1, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 1, 1, 128)         0
#
#  conv2d_7 (Conv2D)           (None, 1, 1, 256)         819456
#
#  dropout_3 (Dropout)         (None, 1, 1, 256)         0
#
#  flatten_1 (Flatten)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 1,540,810
# Trainable params: 1,540,810
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
hist = model.fit(X_train, y_train, epochs = 50, batch_size = 64,validation_data = (X_val , y_val) )
# Out:
# Epoch 1/50
# 110/110 [==============================] - 4s 20ms/step - loss: 1.9898 - accuracy: 0.2248 - val_loss: 1.7033 - val_accuracy: 0.3322
# Epoch 2/50
# 110/110 [==============================] - 1s 13ms/step - loss: 1.6425 - accuracy: 0.3768 - val_loss: 1.3871 - val_accuracy: 0.4914
# Epoch 3/50
# 110/110 [==============================] - 1s 11ms/step - loss: 1.4029 - accuracy: 0.4925 - val_loss: 1.2579 - val_accuracy: 0.5189
50
# 110/110 [==============================] - 1s 12ms/step - loss: 0.2556 - accuracy: 0.9141 - val_loss: 0.4606 - val_accuracy: 0.8729
# Epoch 32/50
# 110/110 [==============================] - 1s 12ms/step - loss: 0.2444 - accuracy: 0.9197 - val_loss: 0.4303 - val_accuracy: 0.8889
# Epoch 33/50
# 110/110 [==============================] - 1s 12ms/step - loss: 0.2291 - accuracy: 0.9280 - val_loss: 0.4130 - val_accuracy: 0.8912
# Epoch 34/50
# 110/110 [==============================] - 1s 12ms/step - loss: 0.2117 - accuracy: 0.9337 - val_loss: 0.4108 - val_accuracy: 0.8946
# Epoch 35/50
# 110/110 [==============================] - 1s 12ms/step - loss: 0.1969 - accuracy: 0.9351 - val_loss: 0.4212 - val_accuracy: 0.8820
# Epoch 36/50
# 110/110 [==============================] - 1s 12ms/step - loss: 0.2161 - accuracy: 0.9288 - val_loss: 0.4229 - val_accuracy: 0.8923
# Epoch 37/50
# 110/110 [==============================] - 1s 12ms/step - loss: 0.1862 - accuracy: 0.9392 - val_loss: 0.4423 - val_accuracy: 0.8809
# Epoch 38/50
# 110/110 [==============================] - 1s 13ms/step - loss: 0.2025 - accuracy: 0.9334 - val_loss: 0.5260 - val_accuracy: 0.8694
# Epoch 39/50
# 110/110 [==============================] - 2s 16ms/step - loss: 0.1979 - accuracy: 0.9350 - val_loss: 0.4161 - val_accuracy: 0.8900
# Epoch 40/50
# 110/110 [==============================] - 1s 14ms/step - loss: 0.1872 - accuracy: 0.9376 - val_loss: 0.4188 - val_accuracy: 0.8912
# Epoch 41/50
# 110/110 [==============================] - 1s 12ms/step - loss: 0.1717 - accuracy: 0.9412 - val_loss: 0.4580 - val_accuracy: 0.8866
# Epoch 42/50
# 110/110 [==============================] - 1s 13ms/step - loss: 0.1678 - accuracy: 0.9439 - val_loss: 0.4108 - val_accuracy: 0.8969
# Epoch 43/50
# 110/110 [==============================] - 1s 12ms/step - loss: 0.1876 - accuracy: 0.9390 - val_loss: 0.4730 - val_accuracy: 0.8729
# Epoch 44/50
# 110/110 [==============================] - 1s 12ms/step - loss: 0.1903 - accuracy: 0.9420 - val_loss: 0.4323 - val_accuracy: 0.8855
# Epoch 45/50
# 110/110 [==============================] - 1s 12ms/step - loss: 0.1716 - accuracy: 0.9440 - val_loss: 0.4442 - val_accuracy: 0.8877
# Epoch 46/50
# 110/110 [==============================] - 1s 13ms/step - loss: 0.1585 - accuracy: 0.9463 - val_loss: 0.4582 - val_accuracy: 0.8866
# Epoch 47/50
# 110/110 [==============================] - 1s 13ms/step - loss: 0.1418 - accuracy: 0.9522 - val_loss: 0.4889 - val_accuracy: 0.8935
# Epoch 48/50
# 110/110 [==============================] - 1s 12ms/step - loss: 0.1650 - accuracy: 0.9435 - val_loss: 0.4843 - val_accuracy: 0.8843
# Epoch 49/50
# 110/110 [==============================] - 1s 12ms/step - loss: 0.1585 - accuracy: 0.9476 - val_loss: 0.4154 - val_accuracy: 0.8923
# Epoch 50/50
# 110/110 [==============================] - 1s 12ms/step - loss: 0.1337 - accuracy: 0.9583 - val_loss: 0.4725 - val_accuracy: 0.8774

# %%
plt.plot(hist.history['accuracy'], label='accuracy')
plt.plot(hist.history['val_accuracy'], label = 'val_accuracy')
plt.title("Train_Accuracy vs Validation_Accuracy")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model_Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# Predict the values from the validation dataset
Y_pred = model.predict(X_val)
# Convert predictions classes to one hot vectors 
Y_pred_classes = np.argmax(Y_pred,axis = 1) 
# Convert validation observations to one hot vectors
Y_true = np.argmax(y_val,axis = 1) 
# compute the confusion matrix
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
# plot the confusion matrix
f,ax = plt.subplots(figsize=(8, 8))
sns.heatmap(confusion_mtx, annot=True, linewidths=0.01,cmap="Greens",linecolor="gray", fmt= '.1f',ax=ax)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 28/28 [==============================] - 0s 9ms/step - loss: 0.4417 - accuracy: 0.8879
# [0.441660612821579, 0.8878718614578247]

# %%
prediction_result = model.predict(X_test[788].reshape(1,28,28,1))

# %%
# Find the predicted class
predicted_class = prediction_result.argmax()
# Find the prediction probability
predicted_probability = prediction_result.max()
print(f"This image belongs to class {predicted_class} with {predicted_probability} probability %")
# Out:
# This image belongs to class 4 with 0.8362773060798645 probability %
